# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # General Social Survey
# `norc.org-gss-2021-1.1.1` Last Update: 2023-03-03T22:02:09
#
# _General Social Survey collects information and keeps a historical record of the concerns, experiences, attitudes, and practices of residents of the United States._
#
#
# ## Documentation Links
#
# * [General Social Survey](https://gss.norc.org/) GSS Homepage at NORC
# * [Download page](https://gss.norc.org/get-the-data/stata)
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [gss_2021](data/gss_2021.csv)**. General Social Survey 2021
#
# ## References
# <ul><li> <strong><a href="https://gss.norc.org/Documents/stata/2021_stata.zip#GSS2021.dta">gss_2021_src</a></strong>. GSS 2021 Source  archive</li><li> <strong><a href="https://gss.norc.org/Documents/stata/2021_stata.zip#GSS 2021 Codebook.pdf">gss_2021_codes</a></strong>. GSS 2021 Codebook</li><li> <strong>_variables</string>, <em>data/variables.csv</em>. Variable names and descriptions</li><li> <strong>_labels</string>, <em>data/labels.csv</em>. Variable value labels</li><ul>

# %%
pkg.resource('gss_2021').dataframe(convert_categorical=True)
# Out:
#       year    id         wrkslf wrkgovt  \
# 0     2021     0   someone else      NA
# 1     2021     1   someone else      NA
# 2     2021     2   someone else      NA
# 3     2021     3  self-employed      NA
# 4     2021     4   someone else      NA
# ...    ...   ...            ...     ...
# 4027  2021  4027             NA      NA
# 4028  2021  4028   someone else      NA
# 4029  2021  4029   someone else      NA
# 4030  2021  4030   someone else      NA
# 4031  2021  4031   someone else      NA
#
#                                               occ10 prestg10  \
# 0              receptionists and information clerks     38.0
# 1               advertising and promotions managers     57.0
# 2          miscellaneous assemblers and fabricators     35.0
# 3                                 childcare workers     35.0
# 4     insurance claims and policy processing clerks     38.0
# ...                                             ...      ...
# 4027                                             NA       NA
# 4028               customer service representatives     31.0
# 4029                            managers, all other     39.0
# 4030                      secondary school teachers     64.0
# 4031                  production workers, all other     35.0
#
#                                         indus10        marital martype  \
# 0                           offices of dentists        married      NA
# 1              advertising and related services       divorced      NA
# 2         furniture and home furnishings stores  never married      NA
# 3                       child day care services        widowed      NA
# 4     insurance carriers and related activities  never married      NA
# ...                                         ...            ...     ...
# 4027                                         NA  never married      NA
# 4028                        electronic shopping        married      NA
# 4029  pharmaceutical and medicine manufacturing        married      NA
# 4030           elementary and secondary schools       divorced      NA
# 4031        miscellaneous manufacturing, n.e.c.        married      NA
#
#      divorce  ...        relitennv        biblenv postlifenv       kidssolnv  \
# 0         no  ...  not very strong  inspired word         no  somewhat worse
# 1         NA  ...      no religion             NA         NA              NA
# 2         NA  ...               NA             NA         NA              NA
# 3         no  ...               NA             NA         NA              NA
# 4         NA  ...  not very strong  inspired word        yes              NA
# ...      ...  ...              ...            ...        ...             ...
# 4027      NA  ...  not very strong   ancient book        yes              NA
# 4028      no  ...               NA             NA         NA              NA
# 4029      no  ...               NA             NA         NA              NA
# 4030      NA  ...               NA  inspired word        yes              NA
# 4031      no  ...               NA             NA         NA              NA
#
#            uscitznnv fucitznnv   fepolnv  \
# 0                 NA        NA        NA
# 1                 NA        NA        NA
# 2                 NA        NA  disagree
# 3                 NA        NA        NA
# 4     a u.s. citizen        NA  disagree
# ...              ...       ...       ...
# 4027              NA        NA  disagree
# 4028              NA        NA        NA
# 4029              NA        NA        NA
# 4030              NA        NA  disagree
# 4031              NA        NA        NA
#
#                                        scibnftsv abanyg fileversion
# 0     about equal (phone mode only: volunteered)     no      7221.3
# 1                               benefits greater     NA      7221.3
# 2                                             NA    yes      7221.3
# 3                                             NA     NA      7221.3
# 4                                             NA    yes      7221.3
# ...                                          ...    ...         ...
# 4027                                          NA    yes      7221.3
# 4028                                          NA     NA      7221.3
# 4029                            benefits greater     NA      7221.3
# 4030                                          NA    yes      7221.3
# 4031                            benefits greater     NA      7221.3
#
# [4032 rows x 735 columns]
